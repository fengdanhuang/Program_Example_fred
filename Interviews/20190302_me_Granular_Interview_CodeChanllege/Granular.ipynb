# %%
from PIL import Image

# %%
from PIL.ExifTags import TAGS

# %%
def get_exif(fn):
    ret = {}
    i = Image.open(fn)
    info = i._getexif()
    if info is not None:
        for tag, value in info.items():
            decoded = TAGS.get(tag, tag)
            ret[decoded] = value
        return ret

# %%
img = Image.open('/Users/chaofeng/Desktop/imgs_de/corn/27937356207_b6674608bb_z.jpg')

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
exif_data = img._getexif()

# %%
exif_data
if exif_data is None:print('None')
else: print(exif_data)
# Out:
# None

# %%
import PIL.ExifTags
exif = {
    PIL.ExifTags.TAGS[k]: v
    for k, v in img._getexif().items()
    if k in PIL.ExifTags.TAGS
}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-fe6a874cd93b> in <module>
#       2 exif = {
#       3     PIL.ExifTags.TAGS[k]: v
# ----> 4     for k, v in img._getexif().items()
#       5     if k in PIL.ExifTags.TAGS
#       6 }
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %%
get_exif('/Users/chaofeng/Desktop/imgs_de/corn/27937356207_b6674608bb_z.jpg')

# %%
import glob
import cv2

# %%
images = [cv2.imread(file) for file in glob.glob('/Users/chaofeng/Desktop/imgs_de/corn/*.jpg')]

# %%
type(images)
# Out:
# list

# %%
len(images)
# Out:
# 48

# %%
type(images[0])
# Out:
# numpy.ndarray

# %%
images[0].shape
# Out:
# (360, 640, 3)

# %%
imgs = [Image.open(file) for file in glob.glob('/Users/chaofeng/Desktop/imgs_de/corn/*.jpg')]

# %%
type(imgs)
# Out:
# list

# %%
type(imgs[0])
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import exifread

# %%
tags = exifread.process_file(open('/Users/chaofeng/Desktop/imgs_de/corn/27937356207_b6674608bb_z.jpg', 'rb'))

# %%
type(tags)
# Out:
# dict

# %%
len(tags)
# Out:
# 0

# %%
import glob, os
for filename in glob.iglob('/Users/chaofeng/Desktop/imgs_de/**', recursive=True):
    if os.path.isfile(filename): # filter dirs
        #print(filename)
        im = Image.open(filename)
        #print(im)
        exif_data = im._getexif()
        ''''
        if exif_data is None:print('----------None')
        else: print('-------------',exif_data)
        '''
        
        if exif_data is not None:
            print("====================================")
            print(filename)
            print('------------------------------------')
            print(exif_data)
            print('------------------------------------')
            tags = exifread.process_file(open(filename, 'rb')) 
            geo = {i:tags[i] for i in tags.keys() if i.startswith('GPS')}
            print(geo)
            print('\n')
# Out:
# ...
# /Users/chaofeng/Desktop/imgs_de/soybean/18798224792_e1f5687b11_z.jpg
# ------------------------------------
# {531: 1, 34853: {0: b'\x02\x03\x00\x00', 1: 'N', 2: ((40, 1), (33, 1), (384, 25)), 3: 'W', 4: ((88, 1), (59, 1), (177, 10))}, 296: 2, 282: (72, 1), 283: (72, 1)}
# ------------------------------------
# {'GPS GPSVersionID': (0x0000) Byte=[2, 3, 0, 0] @ 100, 'GPS GPSLatitudeRef': (0x0001) ASCII=N @ 112, 'GPS GPSLatitude': (0x0002) Ratio=[40, 33, 384/25] @ 156, 'GPS GPSLongitudeRef': (0x0003) ASCII=W @ 136, 'GPS GPSLongitude': (0x0004) Ratio=[88, 59, 177/10] @ 180}
#
#
# ...
# /Users/chaofeng/Desktop/imgs_de/soybean/45470724991_6627e4fa62_z.jpg
# ------------------------------------
# {531: 1, 34853: {0: b'\x02\x03\x00\x00', 1: 'N', 2: ((41, 1), (54, 1), (966, 25)), 3: 'W', 4: ((96, 1), (1, 1), (424, 25))}, 296: 2, 282: (72, 1), 283: (72, 1)}
# ------------------------------------
# ...

# %%
from PIL import Image
from PIL.ExifTags import TAGS, GPSTAGS

def get_exif_data(image):
    """Returns a dictionary from the exif data of an PIL Image item. Also converts the GPS Tags"""
    exif_data = {}
    info = image._getexif()
    if info:
        for tag, value in info.items():
            decoded = TAGS.get(tag, tag)
            if decoded == "GPSInfo":
                gps_data = {}
                for t in value:
                    sub_decoded = GPSTAGS.get(t, t)
                    gps_data[sub_decoded] = value[t]

                exif_data[decoded] = gps_data
            else:
                exif_data[decoded] = value

    return exif_data

def _get_if_exist(data, key):
    if key in data:
        return data[key]
		
    return None
	
def _convert_to_degress(value):
    """Helper function to convert the GPS coordinates stored in the EXIF to degress in float format"""
    d0 = value[0][0]
    d1 = value[0][1]
    d = float(d0) / float(d1)

    m0 = value[1][0]
    m1 = value[1][1]
    m = float(m0) / float(m1)

    s0 = value[2][0]
    s1 = value[2][1]
    s = float(s0) / float(s1)

    return d + (m / 60.0) + (s / 3600.0)

def get_lat_lon(exif_data):
    """Returns the latitude and longitude, if available, from the provided exif_data (obtained through get_exif_data above)"""
    lat = None
    lon = None

    if "GPSInfo" in exif_data:		
        gps_info = exif_data["GPSInfo"]

        gps_latitude = _get_if_exist(gps_info, "GPSLatitude")
        gps_latitude_ref = _get_if_exist(gps_info, 'GPSLatitudeRef')
        gps_longitude = _get_if_exist(gps_info, 'GPSLongitude')
        gps_longitude_ref = _get_if_exist(gps_info, 'GPSLongitudeRef')

        if gps_latitude and gps_latitude_ref and gps_longitude and gps_longitude_ref:
            lat = _convert_to_degress(gps_latitude)
            if gps_latitude_ref != "N":                     
                lat = 0 - lat

            lon = _convert_to_degress(gps_longitude)
            if gps_longitude_ref != "E":
                lon = 0 - lon

    return lat, lon

import pandas as pd

plist=[]
for filename in glob.iglob('/Users/chaofeng/Desktop/imgs_de/**', recursive=True):
    if os.path.isfile(filename): # filter dirs
        im = Image.open(filename)
        #exif_data = im._getexif()
        exif_data = get_exif_data(im)
        if exif_data is not None:
            '''
            print("====================================")
            print(filename)
            print('------------------------------------')
            '''
            #print(exif_data)
            #print (get_lat_lon(exif_data))
            (lan, lon) = get_lat_lon(exif_data)
            if lan is not None and lon is not None:
                l = list(get_lat_lon(exif_data))
                plist.append(l)
                #print (l)
            #print('------------------------------------')             

df = pd.DataFrame(plist,columns=['latitude','longitude'])
print(df)
# Out:
#      latitude   longitude
# 0   40.554267  -88.988250
# 1   41.910733  -96.021378
# 2   41.911378  -96.021872
# 3   39.119514  -77.954681
# 4   39.140147  -77.327750
# 5   42.729314  -84.876769
# 6   39.721144  -92.156617
# 7   39.354808  -94.976372
# 8   41.404069  -85.521606
# 9   40.554267  -88.988250
# 10  43.016833  -80.902167
# 11  42.729314  -84.876769
# 12  39.119697  -77.954122
# 13  43.691850  -85.447389
# 14  43.454114  -92.246883
# 15  41.657578  -83.919622
# 16  39.140653  -77.329986
# 17  43.685250  -85.410942
# 18  37.800203 -121.476050
# 19  49.818119 -103.736686
# 20  47.496475 -117.442872
# 21  38.541125 -106.901044
# 22  27.261667 -109.927222
# 23  33.266622 -112.798878
# 24  41.502664 -122.549431
# 25  48.424122  -71.884689
# 26  48.424197  -71.883300
# 27  45.133728 -113.789039
# 28  38.556081 -121.901847
# 29  38.484675 -104.441319
# ..        ...         ...
# 50  46.890939 -117.332636
# 51  44.456006  -94.735508
# 52  46.801689 -117.142556
# ...

# %%
import gmaps
import gmaps.datasets
import pandas

# %%
gmaps.configure(api_key='AIzaSyDlRBgZKNxixKNe0lOIqBr5xOKW4_sSsYM')

# %%
locations = df

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations))

# %%
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
